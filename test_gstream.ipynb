# %%
from video import Video
from matplotlib import pyplot as plt
from time import sleep
from lane_following import process_image
import cv2

# %%
video = Video()
print("Initialising stream...")

waited = 0

while not video.frame_available():
    waited += 1
    print("\r  Frame not available (x{})".format(waited), end="")
    sleep(0.1)

    # cv2.waitKey(30)

    if waited > 100:
        print("failed")
        break

print('\nSuccess!\nStarting streaming - press "q" to quit.')
# Out:
# Initialising stream...
#   Frame not available (x1)
# Success!
# Starting streaming - press "q" to quit.

# %%
if video.frame_available():
    # Only retrieve and display a frame if it's new
    frame = video.frame()

    # frame = cv2.imread("saved_image.png")

    plt.imshow(frame)
    plt.show()

    b, m, processed_image = process_image(frame)

plt.imshow(processed_image)
# Out:
# /home/vismay/argonauts_bwsi/lane_detection.py:56: RuntimeWarning: divide by zero encountered in scalar divide
#   b = x1 + ((height - y1) / m)
# /home/vismay/argonauts_bwsi/lane_detection.py:104: RuntimeWarning: divide by zero encountered in scalar divide
#   abs(1 / slopes[i_1] - 1 / slopes[i_0]) < m_tol
# /home/vismay/argonauts_bwsi/lane_detection.py:91: RuntimeWarning: divide by zero encountered in scalar divide
#   or (abs(1 / slopes[i_0]) > horizontal_tol)
# [[[450, 275, 639, 228]], [[216, 333, 418, 286]]]
